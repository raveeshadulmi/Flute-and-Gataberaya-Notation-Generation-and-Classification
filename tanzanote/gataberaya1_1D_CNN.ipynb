# %%
# !pip install tensorflow==2.14.0 keras==2.14.0
# Out:
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting keras==2.14.0
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (18.1.1)
# Collecting ml-dtypes==0.2.0 (from tensorflow==2.14.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.14.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.68.0)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow==2.14.0)
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow==2.14.0)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.0) (0.45.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow==2.14.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.2.2)
# Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 1.4 MB/s eta 0:00:00
# Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.8 MB/s eta 0:00:00
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 51.1 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 24.8 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.9 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.68 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.14.0 ml-dtypes-0.2.0 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 wrapt-1.14.1

# %%
# prompt: google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Paths
Thath = '/content/drive/MyDrive/Gataberaya Classification/gataberaya/Thath'
Jith = '/content/drive/MyDrive/Gataberaya Classification/gataberaya/Jith'
Dom = '/content/drive/MyDrive/Gataberaya Classification/gataberaya/Dom'
Nang = '/content/drive/MyDrive/Gataberaya Classification/gataberaya/Nang'

# Function to count audio files
def count_audio_files(path):
    return len([f for f in os.listdir(path) if f.endswith('.wav')])

# Count files in each path
Thath_count = count_audio_files(Thath)
Jith_count = count_audio_files(Jith)
Dom_count = count_audio_files(Dom)
Nang_count = count_audio_files(Nang)

print(f"Number of audio files in Thath path: {Thath_count}")
print(f"Number of audio files in Jith path: {Jith_count}")
print(f"Number of audio files in Dom path: {Dom_count}")
print(f"Number of audio files in Nang path: {Nang_count}")
# Out:
# Number of audio files in Thath path: 56
# Number of audio files in Jith path: 56
# Number of audio files in Dom path: 56
# Number of audio files in Nang path: 56

# %%
import os
import random


# Function to count audio files
def count_audio_files(path):
    # Simulating file count instead of actual directory access
    files = [f for f in os.listdir(path) if f.endswith('.wav')]
    return len(files), files

# Function to simulate file duplication and store in variable
def simulate_duplicate_files(files, target_count):
    current_count = len(files)
    if current_count >= target_count:
        return files  # No duplication needed, return the original list

    # Calculate how many duplicates are needed
    num_duplicates = target_count - current_count
    print(f"Simulating duplication of {num_duplicates} files")

    duplicated_files = files.copy()  # Start with the original list of files
    # Simulate duplicating files
    while num_duplicates > 0:
        file_to_duplicate = random.choice(files)
        new_file_name = f"copy_{num_duplicates}_{file_to_duplicate}"
        duplicated_files.append(new_file_name)
        num_duplicates -= 1

    return duplicated_files

# Get the file counts and lists of files in each path
Thath_count, Thath_files = count_audio_files(Thath)
Jith_count, Jith_files = count_audio_files(Jith)
Dom_count, Dom_files = count_audio_files(Dom)
Nang_count, Nang_files = count_audio_files(Nang)

# Find the maximum number of files in any class
max_files = max(Thath_count, Jith_count, Dom_count, Nang_count)

# Simulate duplicating files to match the maximum number of files
Thath_simulated_files = simulate_duplicate_files(Thath_files, max_files)
Jith_simulated_files = simulate_duplicate_files(Jith_files, max_files)
Dom_simulated_files = simulate_duplicate_files(Dom_files, max_files)
Nang_simulated_files = simulate_duplicate_files(Nang_files, max_files)

# Print the results
print(f"Simulated number of files in Thath path: {len(Thath_simulated_files)}")
print(f"Simulated number of files in Jith path: {len(Jith_simulated_files)}")
print(f"Simulated number of files in Dom path: {len(Dom_simulated_files)}")
print(f"Simulated number of files in Nang path: {len(Nang_simulated_files)}")

# You now have the duplicated files stored in variables without writing to disk.
# Out:
# Simulated number of files in Thath path: 56
# Simulated number of files in Jith path: 56
# Simulated number of files in Dom path: 56
# Simulated number of files in Nang path: 56

# %%
import os
import shutil  # For copying files

# Mount Google Drive if needed (for Google Colab)
from google.colab import drive
drive.mount('/content/drive')

# Base directory where the original files are stored
base_dir = '/content/drive/MyDrive/Gataberaya Classification/gataberaya1'

# Directory where the simulated files will be saved
save_dir = '/content/drive/MyDrive/Gataberaya Classification/gataberaya_augmented'

# Ensure the destination directory exists
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Function to save duplicated files
def save_simulated_files(simulated_files, original_path, save_path):
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    for file_name in simulated_files:
        original_file_path = os.path.join(original_path, file_name.replace('copy_', '').split('_')[-1])
        simulated_file_path = os.path.join(save_path, file_name)

        if os.path.exists(original_file_path):
            # Copy the original file to the new path with the new name
            shutil.copy(original_file_path, simulated_file_path)
        else:
            print(f"Original file not found: {original_file_path}")

# Define paths for the new folders where augmented files will be saved
Thath_save_path = os.path.join(save_dir, 'Thath')
Jith_save_path = os.path.join(save_dir, 'Jith')
Dom_save_path = os.path.join(save_dir, 'Dom')
Nang_save_path = os.path.join(save_dir, 'Nang')

# Save the files for each category
save_simulated_files(Thath_simulated_files, os.path.join(base_dir, 'Thath'), Thath_save_path)
save_simulated_files(Jith_simulated_files, os.path.join(base_dir, 'Jith'), Jith_save_path)
save_simulated_files(Dom_simulated_files, os.path.join(base_dir, 'Dom'), Dom_save_path)
save_simulated_files(Nang_simulated_files, os.path.join(base_dir, 'Nang'), Nang_save_path)

print("Simulated files saved successfully.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-7.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath4-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath4-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath4-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath4-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup8.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup27.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup59.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup42.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup66.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup22.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup52.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup31.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup21.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup16.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup12.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup45.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup14.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup56.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup38.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup25.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup76.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup74.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup70.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup77.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath4-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup74.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup14.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup45.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup21.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 1-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 2-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/dup25.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Thath/Thath 3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2 -1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2 -2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup48.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup37.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup29.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup55.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup19.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup49.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup44.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup26.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup86.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup80.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup71.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup79.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup84.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup67.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup75.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup85.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup69.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup83.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup82.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup49.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup69.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup49.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup75.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup82.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup84.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup55.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith 1-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup44.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/dup44.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Jith/Jith2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1 - 2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1 -1 .wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1 -3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1 -4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom1-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom2-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom2-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom2-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom3-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom3-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom3-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom4-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom4-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom4-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom4-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dom4-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/Dom5-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/Dom5-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/Dom5-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/Dom5-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/Dom5-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup0.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup7.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup9.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup10.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup35.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup57.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup58.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup65.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup17.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup60.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup28.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup41.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup34.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup53.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup63.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup51.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup62.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup33.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup40.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup61.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup50.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup24.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup23.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup64.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup20.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup47.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup81.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Dom/dup73.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-6.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-5.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup11.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup32.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup39.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup36.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup54.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup13.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup15.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup18.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup30.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup43.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup46.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup68.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup72.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup78.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup30.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup36.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-1.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-2.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup43.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup68.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup39.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang2-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup72.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup11.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup30.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup15.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup13.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup39.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup32.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang1-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-4.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup72.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/dup54.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-3.wav
# Original file not found: /content/drive/MyDrive/Gataberaya Classification/gataberaya1/Nang/Nang3-3.wav
# Simulated files saved successfully.

# %%
import os
import numpy as np
import librosa

# Audio augmentation functions
def add_noise(audio, noise_level=0.005):
    """Add random noise to the audio."""
    noise = np.random.randn(len(audio))
    return audio + noise_level * noise

def shift_audio(audio, shift_max=0.5):
    """Shift the audio by a random fraction."""
    shift = np.random.uniform(-shift_max, shift_max) * len(audio)
    return np.roll(audio, int(shift))

def change_pitch(audio, sr, n_steps=2):
    """Change the pitch of the audio."""
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

def change_speed(audio, speed_factor=1.2):
    """Change the speed of the audio."""
    return librosa.effects.time_stretch(audio, rate=speed_factor)

# Function to apply a specific augmentation to audio files
def apply_augmentation(original_files, augmentation_fn, *args):
    """Apply an augmentation function to each audio file."""
    augmented_files = []

    for file_name in original_files:
        try:
            audio, sr = librosa.load(file_name, sr=None)  # Load the audio file
            if augmentation_fn == change_speed:
                augmented_audio = augmentation_fn(audio, *args)  # No need for sample rate in speed change
            else:
                augmented_audio = augmentation_fn(audio, sr, *args)
            augmented_files.append((augmented_audio, sr))
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

    return augmented_files

# Define all augmentation techniques
augmentations = [
    {"name": "noisy", "function": add_noise},
    {"name": "shifted", "function": shift_audio},
    {"name": "pitched", "function": change_pitch, "params": [2]},  # Change pitch by 2 steps
    {"name": "speed_changed", "function": change_speed, "params": [1.2]},  # Change speed by 1.2x
]

# Original file sets for each category
categories = {
    "Thath": Thath_simulated_files,
    "Jith": Jith_simulated_files,
    "Dom": Dom_simulated_files,
    "Nang": Nang_simulated_files,
}

# Dictionary to store augmented files for each category
augmented_files = {key: [] for key in categories}

# Apply augmentations to each category
for category_name, original_files in categories.items():
    print(f"Applying augmentations to {category_name}...")

    # Apply each augmentation technique
    for aug in augmentations:
        aug_name = aug["name"]
        aug_function = aug["function"]
        aug_params = aug.get("params", [])

        augmented = apply_augmentation(original_files, aug_function, *aug_params)

        # Store the augmented files
        augmented_files[category_name].extend(augmented)
        print(f"{aug_name.capitalize()} augmentation applied to {category_name}.")

    # Combine original and augmented files
    augmented_files[category_name].extend(original_files)

# Print the number of files after combining originals and augmented versions
for category_name, files in augmented_files.items():
    print(f"Number of combined {category_name} files: {len(files)}")
# Out:
# Applying augmentations to Thath...
# <ipython-input-7-097dc2fab23d>:31: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_name, sr=None)  # Load the audio file
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#
# Error processing copy_7_Thath 3-3_dup45.wav: [Errno 2] No such file or directory: 'copy_7_Thath 3-3_dup45.wav'
# Error processing copy_6_Thath 3-5_dup21.wav: [Errno 2] No such file or directory: 'copy_6_Thath 3-5_dup21.wav'
# Error processing copy_5_Thath 1-1.wav: [Errno 2] No such file or directory: 'copy_5_Thath 1-1.wav'
# Error processing copy_4_Thath 3-5.wav: [Errno 2] No such file or directory: 'copy_4_Thath 3-5.wav'
# Error processing copy_3_Thath 2-1.wav: [Errno 2] No such file or directory: 'copy_3_Thath 2-1.wav'
# Error processing copy_2_Thath4-1_dup25.wav: [Errno 2] No such file or directory: 'copy_2_Thath4-1_dup25.wav'
# Error processing copy_1_Thath 3-1.wav: [Errno 2] No such file or directory: 'copy_1_Thath 3-1.wav'
# Speed_changed augmentation applied to Thath.
# Applying augmentations to Jith...
# Error processing Jith 1-1.wav: [Errno 2] No such file or directory: 'Jith 1-1.wav'
# Error processing Jith 1-2.wav: [Errno 2] No such file or directory: 'Jith 1-2.wav'
# Error processing Jith 1-3.wav: [Errno 2] No such file or directory: 'Jith 1-3.wav'
# Error processing Jith 1-4.wav: [Errno 2] No such file or directory: 'Jith 1-4.wav'
# Error processing Jith 1-5.wav: [Errno 2] No such file or directory: 'Jith 1-5.wav'
# Error processing Jith 1-6.wav: [Errno 2] No such file or directory: 'Jith 1-6.wav'
# Error processing Jith2 -1.wav: [Errno 2] No such file or directory: 'Jith2 -1.wav'
# Error processing Jith2 -2.wav: [Errno 2] No such file or directory: 'Jith2 -2.wav'
# Error processing Jith2-3.wav: [Errno 2] No such file or directory: 'Jith2-3.wav'
# Error processing Jith2-4.wav: [Errno 2] No such file or directory: 'Jith2-4.wav'
# Error processing Jith2-5.wav: [Errno 2] No such file or directory: 'Jith2-5.wav'
# Error processing Jith2-6.wav: [Errno 2] No such file or directory: 'Jith2-6.wav'
# Error processing Jith3-1.wav: [Errno 2] No such file or directory: 'Jith3-1.wav'
# Error processing Jith3-2.wav: [Errno 2] No such file or directory: 'Jith3-2.wav'
# Error processing Jith3-3.wav: [Errno 2] No such file or directory: 'Jith3-3.wav'
# Error processing Jith3-4.wav: [Errno 2] No such file or directory: 'Jith3-4.wav'
# Error processing Jith3-5.wav: [Errno 2] No such file or directory: 'Jith3-5.wav'
# Error processing Jith2-4_dup2.wav: [Errno 2] No such file or directory: 'Jith2-4_dup2.wav'
# Error processing Jith3-1_dup48.wav: [Errno 2] No such file or directory: 'Jith3-1_dup48.wav'
# Error processing Jith 1-3_dup37.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup37.wav'
# Error processing Jith3-1_dup29.wav: [Errno 2] No such file or directory: 'Jith3-1_dup29.wav'
# Error processing Jith2 -1_dup55.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup55.wav'
# Error processing Jith 1-1_dup19.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup19.wav'
# Error processing Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup49.wav'
# Error processing Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 
jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'copy_2_Jith 1-5_dup44.wav'
# Error processing copy_1_Jith2-4.wav: [Errno 2] No such file or directory: 'copy_1_Jith2-4.wav'
# Noisy augmentation applied to Jith.
# Error processing Jith 1-1.wav: [Errno 2] No such file or directory: 'Jith 1-1.wav'
# Error processing Jith 1-2.wav: [Errno 2] No such file or directory: 'Jith 1-2.wav'
# Error processing Jith 1-3.wav: [Errno 2] No such file or directory: 'Jith 1-3.wav'
# Error processing Jith 1-4.wav: [Errno 2] No such file or directory: 'Jith 1-4.wav'
# Error processing Jith 1-5.wav: [Errno 2] No such file or directory: 'Jith 1-5.wav'
# Error processing Jith 1-6.wav: [Errno 2] No such file or directory: 'Jith 1-6.wav'
# Error processing Jith2 -1.wav: [Errno 2] No such file or directory: 'Jith2 -1.wav'
# Error processing Jith2 -2.wav: [Errno 2] No such file or directory: 'Jith2 -2.wav'
# Error processing Jith2-3.wav: [Errno 2] No such file or directory: 'Jith2-3.wav'
# Error processing Jith2-4.wav: [Errno 2] No such file or directory: 'Jith2-4.wav'
# Error processing Jith2-5.wav: [Errno 2] No such file or directory: 'Jith2-5.wav'
# Error processing Jith2-6.wav: [Errno 2] No such file or directory: 'Jith2-6.wav'
# Error processing Jith3-1.wav: [Errno 2] No such file or directory: 'Jith3-1.wav'
# Error processing Jith3-2.wav: [Errno 2] No such file or directory: 'Jith3-2.wav'
# Error processing Jith3-3.wav: [Errno 2] No such file or directory: 'Jith3-3.wav'
# Error processing Jith3-4.wav: [Errno 2] No such file or directory: 'Jith3-4.wav'
# Error processing Jith3-5.wav: [Errno 2] No such file or directory: 'Jith3-5.wav'
# Error processing Jith2-4_dup2.wav: [Errno 2] No such file or directory: 'Jith2-4_dup2.wav'
# Error processing Jith3-1_dup48.wav: [Errno 2] No such file or directory: 'Jith3-1_dup48.wav'
# Error processing Jith 1-3_dup37.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup37.wav'
# Error processing Jith3-1_dup29.wav: [Errno 2] No such file or directory: 'Jith3-1_dup29.wav'
# Error processing Jith2 -1_dup55.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup55.wav'
# Error processing Jith 1-1_dup19.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup19.wav'
# Error processing Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup49.wav'
# Error processing Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'Jith 1-5_dup44.wav'
# Error processing Jith2-3_dup26.wav: [Errno 2] No such file or directory: 'Jith2-3_dup26.wav'
# Error processing Jith3-3_dup86.wav: [Errno 2] No such file or directory: 'Jith3-3_dup86.wav'
# Error processing Jith 1-1_dup80.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup80.wav'
# Error processing Jith2-5_dup71.wav: [Errno 2] No such file or directory: 'Jith2-5_dup71.wav'
# Error processing Jith 1-2_dup79.wav: [Errno 2] No such file or directory: 'Jith 1-2_dup79.wav'
# Error processing Jith 1-3_dup84.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup84.wav'
# Error processing Jith3-2_dup67.wav: [Errno 2] No such file or directory: 'Jith3-2_dup67.wav'
# Error processing Jith2 -1_dup75.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup75.wav'
# Error processing Jith3-5_dup85.wav: [Errno 2] No such file or directory: 'Jith3-5_dup85.wav'
# Error processing Jith 1-6_dup69.wav: [Errno 2] No such file or directory: 'Jith 1-6_dup69.wav'
# Error processing Jith 1-4_dup83.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup83.wav'
# Error processing Jith3-1_dup82.wav: [Errno 2] No such file or directory: 'Jith3-1_dup82.wav'
# Error processing copy_19_Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 
# Error processing Jith2-4.wav: [Errno 2] No such file or directory: 'Jith2-4.wav'
# Error processing Jith2-5.wav: [Errno 2] No such file or directory: 'Jith2-5.wav'
# Error processing Jith2-6.wav: [Errno 2] No such file or directory: 'Jith2-6.wav'
# Error processing Jith3-1.wav: [Errno 2] No such file or directory: 'Jith3-1.wav'
# Error processing Jith3-2.wav: [Errno 2] No such file or directory: 'Jith3-2.wav'
# Error processing Jith3-3.wav: [Errno 2] No such file or directory: 'Jith3-3.wav'
# Error processing Jith3-4.wav: [Errno 2] No such file or directory: 'Jith3-4.wav'
# Error processing Jith3-5.wav: [Errno 2] No such file or directory: 'Jith3-5.wav'
# Error processing Jith2-4_dup2.wav: [Errno 2] No such file or directory: 'Jith2-4_dup2.wav'
# Error processing Jith3-1_dup48.wav: [Errno 2] No such file or directory: 'Jith3-1_dup48.wav'
# Error processing Jith 1-3_dup37.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup37.wav'
# Error processing Jith3-1_dup29.wav: [Errno 2] No such file or directory: 'Jith3-1_dup29.wav'
# Error processing Jith2 -1_dup55.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup55.wav'
# Error processing Jith 1-1_dup19.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup19.wav'
# Error processing Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup49.wav'
# Error processing Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'Jith 1-5_dup44.wav'
# Error processing Jith2-3_dup26.wav: [Errno 2] No such file or directory: 'Jith2-3_dup26.wav'
# Error processing Jith3-3_dup86.wav: [Errno 2] No such file or directory: 'Jith3-3_dup86.wav'
# Error processing Jith 1-1_dup80.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup80.wav'
# Error processing Jith2-5_dup71.wav: [Errno 2] No such file or directory: 'Jith2-5_dup71.wav'
# Error processing Jith 1-2_dup79.wav: [Errno 2] No such file or directory: 'Jith 1-2_dup79.wav'
# Error processing Jith 1-3_dup84.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup84.wav'
# Error processing Jith3-2_dup67.wav: [Errno 2] No such file or directory: 'Jith3-2_dup67.wav'
# Error processing Jith2 -1_dup75.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup75.wav'
# Error processing Jith3-5_dup85.wav: [Errno 2] No such file or directory: 'Jith3-5_dup85.wav'
# Error processing Jith 1-6_dup69.wav: [Errno 2] No such file or directory: 'Jith 1-6_dup69.wav'
# Error processing Jith 1-4_dup83.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup83.wav'
# Error processing Jith3-1_dup82.wav: [Errno 2] No such file or directory: 'Jith3-1_dup82.wav'
# Error processing copy_19_Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'copy_19_Jith 1-4_dup49.wav'
# Error processing copy_18_Jith2-6.wav: [Errno 2] No such file or directory: 'copy_18_Jith2-6.wav'
# Error processing copy_17_Jith2-5.wav: [Errno 2] No such file or directory: 'copy_17_Jith2-5.wav'
# Error processing copy_16_Jith2-4.wav: [Errno 2] No such file or directory: 'copy_16_Jith2-4.wav'
# Error processing copy_15_Jith 1-6_dup69.wav: [Errno 2] No such file or directory: 'copy_15_Jith 1-6_dup69.wav'
# Error processing copy_14_Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 
# Error processing Jith 1-3_dup37.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup37.wav'
# Error processing Jith3-1_dup29.wav: [Errno 2] No such file or directory: 'Jith3-1_dup29.wav'
# Error processing Jith2 -1_dup55.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup55.wav'
# Error processing Jith 1-1_dup19.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup19.wav'
# Error processing Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup49.wav'
# Error processing Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'Jith 1-5_dup44.wav'
# Error processing Jith2-3_dup26.wav: [Errno 2] No such file or directory: 'Jith2-3_dup26.wav'
# Error processing Jith3-3_dup86.wav: [Errno 2] No such file or directory: 'Jith3-3_dup86.wav'
# Error processing Jith 1-1_dup80.wav: [Errno 2] No such file or directory: 'Jith 1-1_dup80.wav'
# Error processing Jith2-5_dup71.wav: [Errno 2] No such file or directory: 'Jith2-5_dup71.wav'
# Error processing Jith 1-2_dup79.wav: [Errno 2] No such file or directory: 'Jith 1-2_dup79.wav'
# Error processing Jith 1-3_dup84.wav: [Errno 2] No such file or directory: 'Jith 1-3_dup84.wav'
# Error processing Jith3-2_dup67.wav: [Errno 2] No such file or directory: 'Jith3-2_dup67.wav'
# Error processing Jith2 -1_dup75.wav: [Errno 2] No such file or directory: 'Jith2 -1_dup75.wav'
# Error processing Jith3-5_dup85.wav: [Errno 2] No such file or directory: 'Jith3-5_dup85.wav'
# Error processing Jith 1-6_dup69.wav: [Errno 2] No such file or directory: 'Jith 1-6_dup69.wav'
# Error processing Jith 1-4_dup83.wav: [Errno 2] No such file or directory: 'Jith 1-4_dup83.wav'
# Error processing Jith3-1_dup82.wav: [Errno 2] No such file or directory: 'Jith3-1_dup82.wav'
# Error processing copy_19_Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'copy_19_Jith 1-4_dup49.wav'
# Error processing copy_18_Jith2-6.wav: [Errno 2] No such file or directory: 'copy_18_Jith2-6.wav'
# Error processing copy_17_Jith2-5.wav: [Errno 2] No such file or directory: 'copy_17_Jith2-5.wav'
# Error processing copy_16_Jith2-4.wav: [Errno 2] No such file or directory: 'copy_16_Jith2-4.wav'
# Error processing copy_15_Jith 1-6_dup69.wav: [Errno 2] No such file or directory: 'copy_15_Jith 1-6_dup69.wav'
# Error processing copy_14_Jith 1-4_dup49.wav: [Errno 2] No such file or directory: 'copy_14_Jith 1-4_dup49.wav'
# Error processing copy_13_Jith2 -1_dup75.wav: [Errno 2] No such file or directory: 'copy_13_Jith2 -1_dup75.wav'
# Error processing copy_12_Jith3-1.wav: [Errno 2] No such file or directory: 'copy_12_Jith3-1.wav'
# Error processing copy_11_Jith3-3.wav: [Errno 2] No such file or directory: 'copy_11_Jith3-3.wav'
# Error processing copy_10_Jith2-6.wav: [Errno 2] No such file or directory: 'copy_10_Jith2-6.wav'
# Error processing copy_9_Jith3-1_dup82.wav: [Errno 2] No such file or directory: 'copy_9_Jith3-1_dup82.wav'
# Error processing copy_8_Jith3-2.wav: [Errno 2] No such file or directory: 'copy_8_Jith3-2.wav'
# Error processing copy_7_Jith 1-3_dup84.wav: [Errno 2] No such file or directory: 'copy_7_Jith 1-3_dup84.wav'
# Error processing copy_6_Jith3-3.wav: [Errno 2] No such file or directory: 'copy_6_Jith3-3.wav'
# Error processing copy_5_Jith2 -1_dup55.wav: [Errno 2] No such file or directory: 'copy_5_Jith2 -1_dup55.wav'
# Error processing copy_4_Jith 1-3.wav: [Errno 2] No such file or directory: 'copy_4_Jith 1-3.wav'
# Error processing copy_3_Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'copy_3_Jith 1-5_dup44.wav'
# Error processing copy_2_Jith 1-5_dup44.wav: [Errno 2] No such file or directory: 'copy_2_Jith 1-5_dup44.wav'
# Error processing copy_1_Jith2-4.wav: [Errno 2] No such file or directory: 'copy_1_Jith2-4.wav'
# Speed_changed augmentation applied to Jith.
# Applying augmentations to Dom...
# Error processing dom1 - 2.wav: [Errno 2] No such file or directory: 'dom1 - 2.wav'
# Error processing dom1 -1 .wav: [Errno 2] No such file or directory: 'dom1 -1 .wav'
# Error processing dom1 -3.wav: [Errno 2] No such file or directory: 'dom1 -3.wav'
# Error processing dom1 -4.wav: [Errno 2] No such file or directory: 'dom1 -4.wav'
# Error processing dom1-5.wav: [Errno 2] No such file or directory: 'dom1-5.wav'
# Error processing dom1-6.wav: [Errno 2] No such file or directory: 'dom1-6.wav'
# Error processing dom2-1.wav: [Errno 2] No such file or directory: 'dom2-1.wav'
# Error processing dom2-2.wav: [Errno 2] No such file or directory: 'dom2-2.wav'
# Error processing dom2-3.wav: [Errno 2] No such file or directory: 'dom2-3.wav'
# Error processing dom2-4.wav: [Errno 2] No such file or directory: 'dom2-4.wav'
# Error processing dom3-1.wav: [Errno 2] No such file or directory: 'dom3-1.wav'
# Error processing dom3-2.wav: [Errno 2] No such file or directory: 'dom3-2.wav'
# Error processing dom3-3.wav: [Errno 2] No such file or directory: 'dom3-3.wav'
# Error processing dom3-4.wav: [Errno 2] No such file or directory: 'dom3-4.wav'
# Error processing dom3-5.wav: [Errno 2] No such file or directory: 'dom3-5.wav'
# Error processing dom4-1.wav: [Errno 2] No such file or directory: 'dom4-1.wav'
# Error processing dom4-2.wav: [Errno 2] No such file or directory: 'dom4-2.wav'
# Error processing dom4-3.wav: [Errno 2] No such file or directory: 'dom4-3.wav'
# Error processing dom4-4.wav: [Errno 2] No such file or directory: 'dom4-4.wav'
# Error processing dom4-5.wav: [Errno 2] No such file or directory: 'dom4-5.wav'
# Error processing Dom5-1.wav: [Errno 2] No such file or directory: 'Dom5-1.wav'
# Error processing Dom5-2.wav: [Errno 2] No such file or directory: 'Dom5-2.wav'
# Error processing Dom5-3.wav: [Errno 2] No such file or directory: 'Dom5-3.wav'
# Error processing Dom5-4.wav: [Errno 2] No such file or directory: 'Dom5-4.wav'
# Error processing Dom5-5.wav: [Errno 2] No such file or directory: 'Dom5-5.wav'
# Error processing dom3-4_dup3.wav: [Errno 2] No such file or directory: 'dom3-4_dup3.wav'
# Error processing dom4-1_dup5.wav: [Errno 2] No such file or directory: 'dom4-1_dup5.wav'
# Error processing dom3-1_dup4.wav: [Errno 2] No such file or directory: 'dom3-1_dup4.wav'
# Error processing Dom5-4_dup0.wav: [Errno 2] No such file or directory: 'Dom5-4_dup0.wav'
# Error processing dom1-5_dup7.wav: [Errno 2] No such file or directory: 'dom1-5_dup7.wav'
# Error processing Dom5-1_dup9.wav: [Errno 2] No such file or directory: 'Dom5-1_dup9.wav'
# Error processing Dom5-2_dup10.wav: [Errno 2] No such file or directory: 'Dom5-2_dup10.wav'
# Error processing dom1 -4_dup35.wav: [Errno 2] No such file or directory: 'dom1 -4_dup35.wav'
# Error processing dom1 -3_dup57.wav: [Errno 2] No such file or directory: 'dom1 -3_dup57.wav'
# Error processing dom1 - 2_dup58.wav: [Errno 2] No such file or directory: 'dom1 - 2_dup58.wav'
# Error processing dom4-3_dup65.wav: [Errno 2] No such file or directory: 'dom4-3_dup65.wav'
# Error processing Dom5-2_dup17.wav: [Errno 2] No such file or directory: 'Dom5-2_dup17.wav'
# Error processing dom2-1_dup60.wav: [Errno 2] No such file or directory: 'dom2-1_dup60.wav'
# Error processing dom2-4_dup28.wav: [Errno 2] No such file or directory: 'dom2-4_dup28.wav'
# Error processing dom1-6_dup41.wav: [Errno 2] No such file or directory: 'dom1-6_dup41.wav'
# Error processing dom1 -4_dup34.wav: [Errno 2] No such file or directory: 'dom1 -4_dup34.wav'
# Error processing dom1 -3_dup53.wav: [Errno 2] No such file or directory: 'dom1 -3_dup53.wav'
# Error processing Dom5-3_dup63.wav: [Errno 2] No such file or directory: 'Dom5-3_dup63.wav'
# Error processing dom1 -3_dup51.wav: [Errno 2] No such file or directory: 'dom1 -3_dup51.wav'
# Error processing Dom5-1_dup62.wav: [Errno 2] No such file or directory: 'Dom5-1_dup62.wav'
# Error processing Dom5-5_dup33.wav: [Errno 2] No such file or directory: 'Dom5-5_dup33.wav'
# Error processing dom1 - 2_dup40.wav: [Errno 2] No such file or directory: 'dom1 - 2_dup40.wav'
# Error processing dom4-3_dup61.wav: [Errno 2] No such file or directory: 'dom4-3_dup61.wav'
# Error processing dom1 -1 _dup50.wav: [Errno 2] No such file or directory: 'dom1 -1 _dup50.wav'
# Error processing dom4-4_dup24.wav: [Errno 2] No such file or directory: 'dom4-4_dup24.wav'
# Error processing dom1 - 2_dup23.wav: [Errno 2] No such file or directory: 'dom1 - 2_dup23.wav'
# Error processing dom1 -3_dup64.wav: [Errno 2] No such file or directory: 'dom1 -3_dup64.wav'
# Error processing dom3-4_dup20.wav: [Errno 2] No such file or directory: 'dom3-4_dup20.wav'
# Error processing Dom5-4_dup47.wav: [Errno 2] No such file or directory: 'Dom5-4_dup47.wav'
# Error processing dom1 - 2_dup81.wav: [Errno 2] No such file or directory: 'dom1 - 2_dup81.wav'
# Error processing dom1-5_dup73.wav: [Errno 2] No such file or directory: 'dom1-5_dup73.wav'
# Noisy augmentation applied to Dom.
# Error processing dom1 - 2.wav: [Errno 2] No such file or directory: 'dom1 - 2.wav'
# Error processing dom1 -1 .wav: [Errno 2] No such file or directory: 'dom1 -1 .wav'
# Error processing dom1 -3.wav: [Errno 2] No such file or directory: 'dom1 -3.wav'
# Error processing copy_14_Nang2-6_dup72.wav: [Errno 2] No such file or directory: 'copy_14_Nang2-6_dup72.wav'
# Error processing copy_13_Nang3-3_dup11.wav: [Errno 2] No such file or directory: 'copy_13_Nang3-3_dup11.wav'
# Error processing copy_12_Nang3-2_dup30.wav: [Errno 2] No such file or directory: 'copy_12_Nang3-2_dup30.wav'
# Error processing copy_11_Nang3-2_dup15.wav: [Errno 2] No such file or directory: 'copy_11_Nang3-2_dup15.wav'
# Error processing copy_10_Nang1-6_dup13.wav: [Errno 2] No such file or directory: 'copy_10_Nang1-6_dup13.wav'
# Error processing copy_9_Nang1-6_dup39.wav: [Errno 2] No such file or directory: 'copy_9_Nang1-6_dup39.wav'
# Error processing copy_8_Nang3-4_dup32.wav: [Errno 2] No such file or directory: 'copy_8_Nang3-4_dup32.wav'
# Error processing copy_7_Nang1-3.wav: [Errno 2] No such file or directory: 'copy_7_Nang1-3.wav'
# Error processing copy_6_Nang1-4.wav: [Errno 2] No such file or directory: 'copy_6_Nang1-4.wav'
# Error processing copy_5_Nang3-4.wav: [Errno 2] No such file or directory: 'copy_5_Nang3-4.wav'
# Error processing copy_4_Nang2-6_dup72.wav: [Errno 2] No such file or directory: 'copy_4_Nang2-6_dup72.wav'
# Error processing copy_3_Nang3-3_dup54.wav: [Errno 2] No such file or directory: 'copy_3_Nang3-3_dup54.wav'
# Error processing copy_2_Nang3-3.wav: [Errno 2] No such file or directory: 'copy_2_Nang3-3.wav'
# Error processing copy_1_Nang3-3.wav: [Errno 2] No such file or directory: 'copy_1_Nang3-3.wav'
# Speed_changed augmentation applied to Nang.
# Number of combined Thath files: 56
# Number of combined Jith files: 56
# Number of combined Dom files: 56
# Number of combined Nang files: 56

# %%
import os
import numpy as np
import librosa


# Function to add noise
def add_noise(audio, noise_level=0.005):
    noise = np.random.randn(len(audio))
    audio_noisy = audio + noise_level * noise
    return audio_noisy

# Function to apply shifting
def shift_audio(audio, shift_max=0.5):
    shift = np.random.uniform(-shift_max, shift_max) * len(audio)
    return np.roll(audio, int(shift))

# Function to change pitch
def change_pitch(audio, sr, n_steps=2):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

# Function to change speed
def change_speed(audio, speed_factor=1.2):
    return librosa.effects.time_stretch(audio, rate=speed_factor)

# Function to load original audio files
def load_original_audio_files(path):
    original_files = []
    for filename in os.listdir(path):
        if filename.endswith('.wav'):
            file_path = os.path.join(path, filename)
            audio, sr = librosa.load(file_path, sr=None)
            original_files.append((audio, sr))
    return original_files

# Function to apply a specific augmentation to audio files
def apply_augmentation(original_files, augmentation_fn, *args):
    augmented_files = []
    for audio, sr in original_files:
        if augmentation_fn == change_speed:
            augmented_audio = augmentation_fn(audio, *args)  # No sample rate needed for speed change
        else:
            augmented_audio = augmentation_fn(audio, sr, *args)
        augmented_files.append((augmented_audio, sr))
    return augmented_files

# Load original audio files
original_Thath_files = load_original_audio_files(Thath)
original_Jith_files = load_original_audio_files(Jith)
original_Dom_files = load_original_audio_files(Dom)
original_Nang_files = load_original_audio_files(Nang)

# Apply each augmentation
Thath_noisy = apply_augmentation(original_Thath_files, add_noise)
Jith_noisy = apply_augmentation(original_Jith_files, add_noise)
Dom_noisy = apply_augmentation(original_Dom_files, add_noise)
Nang_noisy = apply_augmentation(original_Nang_files, add_noise)

Thath_shifted = apply_augmentation(original_Thath_files, shift_audio)
Jith_shifted = apply_augmentation(original_Jith_files, shift_audio)
Dom_shifted = apply_augmentation(original_Dom_files, shift_audio)
Nang_shifted = apply_augmentation(original_Nang_files, shift_audio)

Thath_pitched = apply_augmentation(original_Thath_files, change_pitch, 2)  # You can vary the n_steps
Jith_pitched = apply_augmentation(original_Jith_files, change_pitch, 2)
Dom_pitched = apply_augmentation(original_Dom_files, change_pitch, 2)
Nang_pitched = apply_augmentation(original_Nang_files, change_pitch, 2)

Thath_speed_changed = apply_augmentation(original_Thath_files, change_speed, 1.2)  # No sample rate for speed
Jith_speed_changed = apply_augmentation(original_Jith_files, change_speed, 1.2)
Dom_speed_changed = apply_augmentation(original_Dom_files, change_speed, 1.2)
Nang_speed_changed = apply_augmentation(original_Nang_files, change_speed, 1.2)

# Combine original and augmented files
aug_Thath = (original_Thath_files + Thath_noisy + Thath_shifted + Thath_pitched + Thath_speed_changed)
aug_Jith = (original_Jith_files + Jith_noisy + Jith_shifted + Jith_pitched + Jith_speed_changed)
aug_Dom = (original_Dom_files + Dom_noisy + Dom_shifted + Dom_pitched + Dom_speed_changed)
aug_Nang = (original_Nang_files + Nang_noisy + Nang_shifted + Nang_pitched + Nang_speed_changed)

# Count files after combining
aug_Thath_count = len(aug_Thath)
aug_Jith_count = len(aug_Jith)
aug_Dom_count = len(aug_Dom)
aug_Nang_count = len(aug_Nang)

print(f"Number of combined Thath files: {aug_Thath_count}")
print(f"Number of combined Jith files: {aug_Jith_count}")
print(f"Number of combined Dom files: {aug_Dom_count}")
print(f"Number of combined Nang files: {aug_Nang_count}")
# Out:
# Number of combined Thath files: 280
# Number of combined Jith files: 280
# Number of combined Dom files: 280
# Number of combined Nang files: 280

# %%
import matplotlib.pyplot as plt
import librosa.display
import random

# Function to plot spectrogram
def plot_spectrogram(audio, sr, plot_type='mfcc'):
    if plot_type == 'mfcc':
        features = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
    elif plot_type == 'mel':
        features = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=128)
    else:
        raise ValueError("Invalid plot_type. Choose 'mfcc' or 'mel'.")
    return features

# Function to plot and display spectrograms
def display_spectrograms(audio_files, title_prefix):
    random_indices = random.sample(range(len(audio_files)), 3)
    for i in random_indices:
        audio, sr = audio_files[i]
        print(f"{title_prefix} File {i+1}:")

        # Create subplots for side-by-side comparison
        fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 4))

        # Plot original
        librosa.display.specshow(plot_spectrogram(audio, sr, 'mfcc'),
                                 sr=sr, x_axis='time', y_axis='linear', cmap='magma',
                                 vmin=-100, vmax=0, ax=axes[0])
        axes[0].set_title("Original")
        fig.colorbar(axes[0].get_children()[0], ax=axes[0])

        # Plot noisy
        librosa.display.specshow(plot_spectrogram(add_noise(audio), sr, 'mfcc'),
                                 sr=sr, x_axis='time', y_axis='linear', cmap='magma',
                                 vmin=-100, vmax=0, ax=axes[1])
        axes[1].set_title("Noise Added")
        fig.colorbar(axes[1].get_children()[0], ax=axes[1])

        # Plot shifted
        librosa.display.specshow(plot_spectrogram(shift_audio(audio), sr, 'mfcc'),
                                 sr=sr, x_axis='time', y_axis='linear', cmap='magma',
                                 vmin=-100, vmax=0, ax=axes[2])
        axes[2].set_title("Shifted")
        fig.colorbar(axes[2].get_children()[0], ax=axes[2])

        # Plot pitched
        librosa.display.specshow(plot_spectrogram(change_pitch(audio, sr), sr, 'mfcc'),
                                 sr=sr, x_axis='time', y_axis='linear', cmap='magma',
                                 vmin=-100, vmax=0, ax=axes[3])
        axes[3].set_title("Pitch Changed")
        fig.colorbar(axes[3].get_children()[0], ax=axes[3])

        # Plot speed changed
        librosa.display.specshow(plot_spectrogram(change_speed(audio), sr, 'mfcc'),
                                 sr=sr, x_axis='time', y_axis='linear', cmap='magma',
                                 vmin=-100, vmax=0, ax=axes[4])
        axes[4].set_title("Speed Changed")
        fig.colorbar(axes[4].get_children()[0], ax=axes[4])

        for ax in axes:
            ax.set_xlabel("Time")
            ax.set_ylabel("Frequency")

        plt.tight_layout()
        plt.show()

# Display spectrograms for each class
print("## Thath Spectrograms")
display_spectrograms(aug_Thath, "Thath")

print("\n## Jith Spectrograms")
display_spectrograms(aug_Jith, "Jith")

print("\n## Dom Spectrograms")
display_spectrograms(aug_Dom, "Dom")

print("\n## Nang Spectrograms")
display_spectrograms(aug_Nang, "Nang")
# Out:
# ## Thath Spectrograms
# Thath File 68:
# Thath File 94:
# Thath File 234:
# ## Jith Spectrograms
# Jith File 122:
# Jith File 201:
# Jith File 254:
# ## Dom Spectrograms
# Dom File 67:
# Dom File 21:
# Dom File 226:
# ## Nang Spectrograms
# Nang File 207:
# Nang File 201:
# Nang File 75:

# %%
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Constants
NUM_MFCC = 40
FIXED_LENGTH = 100

# Function to extract fixed-length MFCC features
def extract_mfcc_uniform_length(audio, sr, num_mfcc=NUM_MFCC, fixed_length=FIXED_LENGTH):
    # Extract MFCC features
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=num_mfcc, hop_length=int(len(audio) / fixed_length))
    # Ensure the MFCC length is uniform
    if mfcc.shape[1] == fixed_length:
        return mfcc
    elif mfcc.shape[1] < fixed_length:
        # Pad with zeros if length is shorter than fixed_length
        padding = np.zeros((num_mfcc, fixed_length - mfcc.shape[1]))
        return np.concatenate((mfcc, padding), axis=1)
    else:
        # Truncate if length is longer than fixed_length
        return mfcc[:, :fixed_length]

# Function to extract features from a list of audio files
def extract_features_from_list(audio_files, num_mfcc=NUM_MFCC, fixed_length=FIXED_LENGTH):
    features = []
    for audio, sr in audio_files:
        mfcc = extract_mfcc_uniform_length(audio, sr, num_mfcc, fixed_length)
        features.append(mfcc)
    return features

# Extract features for each class
Thath_features = extract_features_from_list(aug_Thath)
Jith_features = extract_features_from_list(aug_Jith)
Dom_features = extract_features_from_list(aug_Dom)
Nang_features = extract_features_from_list(aug_Nang)

# Create class labels
Thath_labels = ['Thath'] * len(Thath_features)
Jith_labels = ['Jith'] * len(Jith_features)
Dom_labels = ['Dom'] * len(Dom_features)
Nang_labels = ['Nang'] * len(Nang_features)

# Combine features and labels
features_combined = Thath_features + Jith_features + Dom_features + Nang_features
labels_combined = Thath_labels + Jith_labels + Dom_labels + Nang_labels

# Create DataFrame
features_df = pd.DataFrame({
    'Feature': features_combined,
    'Class': labels_combined
})

# Convert DataFrame columns to numpy arrays
m = np.array(features_df['Feature'].tolist())
n = np.array(features_df['Class'].tolist())

# Encode labels
label_encoder = LabelEncoder()
n = label_encoder.fit_transform(n)
n = to_categorical(n)

print(f"Feature array shape: {m.shape}")
print(f"Label array shape: {n.shape}")
# Out:
# Feature array shape: (1120, 40, 100)
# Label array shape: (1120, 4)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Split the data into train and test sets
m_train, m_test, n_train, n_test = train_test_split(m, n, test_size=0.15, random_state=0)

# Split training data into train and validation sets
m_train, m_validation, n_train, n_validation = train_test_split(m_train, n_train, test_size=0.15, random_state=0)

# Reshape data to be suitable for 1D CNN (correct format: samples, time_steps, features)
m_train = np.transpose(m_train, (0, 2, 1))  # From (samples, features, time_steps) to (samples, time_steps, features)
m_test = np.transpose(m_test, (0, 2, 1))
m_validation = np.transpose(m_validation, (0, 2, 1))

# Check the new shapes
print("Shape of m_train after transposing:", m_train.shape)
print("Shape of m_test after transposing:", m_test.shape)
print("Shape of m_validation after transposing:", m_validation.shape)
# Out:
# Shape of m_train after transposing: (809, 100, 40)
# Shape of m_test after transposing: (168, 100, 40)
# Shape of m_validation after transposing: (143, 100, 40)

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

EPOCHS = 50
BATCH_SIZE = 5
NUM_CLASSES = 4
LEARNING_RATE = 0.0001
model = Sequential()
model.add(Conv1D(64, kernel_size=5, padding="same", strides=1, input_shape=(100, 40), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2, strides=2, padding="same"))
model.add(Dropout(0.3))
model.add(Conv1D(32, kernel_size=5, strides=1, padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2, strides=2, padding="same"))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(NUM_CLASSES, activation="softmax"))
optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
print(model.summary())

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(
    m_train, n_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(m_validation, n_validation),
    callbacks=[early_stopping]
)

from sklearn.metrics import classification_report
import numpy as np

# Get predictions for the validation data
y_pred_probs = model.predict(m_validation)  # Get predicted probabilities
y_pred = np.argmax(y_pred_probs, axis=1)    # Convert probabilities to class indices

# Convert one-hot encoded true labels to class indices
y_true = np.argmax(n_validation, axis=1)

# Generate the classification report
report = classification_report(y_true, y_pred, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print(report)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 100, 64)           12864
#
#  batch_normalization (Batch  (None, 100, 64)           256
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 50, 64)            0
#  D)
#
#  dropout (Dropout)           (None, 50, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 50, 32)            10272
#
#  batch_normalization_1 (Bat  (None, 50, 32)            128
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 32)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 25, 32)            0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params:
# Epoch 19/50
# 162/162 [==============================] - 1s 8ms/step - loss: 0.6921 - accuracy: 0.7355 - val_loss: 0.3673 - val_accuracy: 0.8182
# 5/5 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#      Class 1       0.60      0.97      0.74        37
#      Class 2       0.96      0.74      0.84        35
#      Class 3       0.93      0.76      0.84        34
#      Class 4       1.00      0.76      0.86        37
#
#     accuracy                           0.81       143
#    macro avg       0.87      0.81      0.82       143
# weighted avg       0.87      0.81      0.82       143

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Purples", cbar=False,
            annot_kws={"fontsize": 14}, linewidths=2, linecolor='black')

plt.xlabel('Predicted Label', fontsize=16)
plt.ylabel('True Label', fontsize=16)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import seaborn as sns

# Evaluate the model
test_loss, test_accuracy = model.evaluate(m_test, n_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Plot learning curves
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], color='#99627A', label='Training Accuracy')
plt.plot(history.history['val_accuracy'], color='#C88EA7', label='Validation Accuracy')
plt.plot(history.history['loss'], color='#E7CBCB', label='Training Loss')
plt.plot(history.history['val_loss'], color='#A7A7A7', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.title('Learning Curves')
plt.legend()
plt.show()

# Predictions
y_pred = model.predict(m_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(n_test, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve
plt.figure(figsize=(10, 8))
colors = ['#99627A', '#C88EA7', '#E7CBCB', '#A7A7A7']
for i, color in enumerate(colors):
    fpr, tpr, _ = roc_curve(n_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {label_encoder.classes_[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3314 - accuracy: 0.8452
# Test Loss: 0.33136600255966187
# Test Accuracy: 0.8452380895614624
# 6/6 [==============================] - 0s 10ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Define custom colors
colors = ['#99627A', '#C88EA7', '#E7CBCB']
cmap = plt.get_cmap('Blues')  # Use the 'Blues' colormap as base
custom_cmap = sns.color_palette(colors, as_cmap=True)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(m_test, n_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Predictions
y_pred = model.predict(m_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(n_test, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_cmap, xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Plot learning curves
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], color='#99627A', label='Training Accuracy')
plt.plot(history.history['val_accuracy'], color='#C88EA7', label='Validation Accuracy')
plt.plot(history.history['loss'], color='#E7CBCB', label='Training Loss')
plt.plot(history.history['val_loss'], color='#A7A7A7', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.title('Learning Curves')
plt.legend()
plt.show()

# ROC Curve
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))
for i, color in enumerate(colors):
    fpr, tpr, _ = roc_curve(n_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {label_encoder.classes_[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3314 - accuracy: 0.8452
# Test Loss: 0.33136600255966187
# Test Accuracy: 0.8452380895614624
# 6/6 [==============================] - 0s 11ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Define custom colors
colors = ['#99627A', '#C88EA7', '#E7CBCB', '#D9A6A0']
custom_cmap = sns.color_palette(colors, as_cmap=True)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(m_test, n_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Predictions
y_pred = model.predict(m_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(n_test, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_cmap, xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Plot learning curves
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], color='#99627A', label='Training Accuracy')
plt.plot(history.history['val_accuracy'], color='#C88EA7', label='Validation Accuracy')
plt.plot(history.history['loss'], color='#E7CBCB', label='Training Loss')
plt.plot(history.history['val_loss'], color='#D9A6A0', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.title('Learning Curves')
plt.legend()
plt.show()

# ROC Curve
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))
for i, color in enumerate(colors):
    fpr, tpr, _ = roc_curve(n_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {label_encoder.classes_[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3314 - accuracy: 0.8452
# Test Loss: 0.33136600255966187
# Test Accuracy: 0.8452380895614624
# 6/6 [==============================] - 0s 11ms/step

# %%
from sklearn.metrics import roc_curve, auc

# Assuming y_true and y_pred_prob are available for ROC curve
# y_pred_prob should be the predicted probabilities for each class

colors = ['#99627A', '#C88EA7', '#E7CBCB']
plt.figure(figsize=(10, 8))

for i, color in enumerate(colors):
    fpr, tpr, _ = roc_curve(y_true[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curves', fontsize=16)
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-bd04e30fbd43> in <cell line: 9>()
#       8
#       9 for i, color in enumerate(colors):
# ---> 10     fpr, tpr, _ = roc_curve(y_true[:, i], y_pred_prob[:, i])
#      11     roc_auc = auc(fpr, tpr)
#      12     plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# Save the model
model_save_path = '/content/gataberaya2.h5'
model.save(model_save_path)

print(f"Model saved as {model_save_path}")
# Out:
# Model saved as /content/gataberaya2.h5

# %%
import numpy as np
import librosa
from keras.models import load_model

# Function to extract MFCC features from an audio file
def extract_features(file_path, max_pad_len=100):
    # Load audio file
    audio, sample_rate = librosa.load(file_path, sr=None)
    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    # Padding to ensure uniform length
    pad_width = max_pad_len - mfccs.shape[1]
    if pad_width > 0:
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    else:
        mfccs = mfccs[:, :max_pad_len]
    return mfccs.T  # Transpose to have the shape (max_pad_len, n_mfcc)
# Load your trained model
model_path = '/content/gataberaya2.h5'
# Path to the unseen audio file
unseen_audio_path = '/content/NANG1.wav'  # Update this path as needed
# Extract features from the unseen audio file
features = extract_features(unseen_audio_path)
# Reshape features to match input shape expected by the model
features_reshaped = features[np.newaxis, ..., np.newaxis]  # Add batch and channel dimensions
# Make a prediction
prediction = model.predict(features_reshaped)
# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)
# Map numerical class to instrument names
class_names = ['Thath', 'Jith', 'Dom', 'Nang']
predicted_label = class_names[predicted_class[0]]
model_path = '/content/gataberaya2.h5'
unseen_audio_path = '/content/NANG1.wav'
print(f"The predicted class for the unseen audio file is: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 167ms/step
# The predicted class for the unseen audio file is: Jith
